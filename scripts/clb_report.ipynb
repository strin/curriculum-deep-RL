# %%
import scriptinit
import clb

# %%
uuids = ['0x85217d0e764647f283239b9d0423db36', '0xa48e15ec8a014a1aba8fde8c9d5571c6']
clb.report(uuids)
# Out:
# ...
# 0xa48e15ec8a014a1aba8fde8c9d5571c6
# http://localhost:18000/bundles/0xa48e15ec8a014a1aba8fde8c9d5571c6/
# name: test_hypercube_code
# state: running
# time: 1032.0
# remote: jude35.s
# uuid: 0xa48e15
# gb_used: 0.0757713317871
# ...
# 0x85217d0e764647f283239b9d0423db36
# http://localhost:18000/bundles/0x85217d0e764647f283239b9d0423db36/
# name: small_hypercube_test
# state: ready
# time: 70.0
# remote: jude34.s
# uuid: 0x85217d
# gb_used: 0.0796089172363
